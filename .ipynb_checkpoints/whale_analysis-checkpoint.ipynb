# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whalereturns_path = Path("Resources/whale_returns.csv")

whalereturns_df = pd.read_csv(whalereturns_path)
whalereturns_df.count()

whalereturns_df.set_index(pd.to_datetime(whalereturns_df['Date'], infer_datetime_format=True), inplace=True)
whalereturns_df.drop(columns=['Date'], inplace=True)
whalereturns_df.sort_index(inplace=True)
whalereturns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whalereturns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whalereturns_df = whalereturns_df.dropna().copy()
# Count nulls
print(whalereturns_df.isnull().sum())
whalereturns_df.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algoreturns_path = Path("Resources/algo_returns.csv")

algoreturns_df = pd.read_csv(algoreturns_path)
print(algoreturns_df.count())
algoreturns_df.dtypes
algoreturns_df.set_index(pd.to_datetime(algoreturns_df['Date'], infer_datetime_format=True), inplace=True)
algoreturns_df.drop(columns=['Date'], inplace=True)
algoreturns_df.sort_index(inplace=True)
algoreturns_df.head()
# Out:
# Date      1241
# Algo 1    1241
# Algo 2    1235
# dtype: int64
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algoreturns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algoreturns_df = algoreturns_df.dropna().copy()
print(algoreturns_df.isnull().sum())
algoreturns_df.head()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500returns_path = Path("Resources/sp500_history.csv")

sp500_df = pd.read_csv(sp500returns_path)
print(sp500_df.count())
sp500_df.set_index(pd.to_datetime(sp500_df['Date'], infer_datetime_format=True), inplace=True)
sp500_df.drop(columns=['Date'], inplace=True)
sp500_df.sort_index(inplace=True)
sp500_df.head()
# Out:
# Date     1649
# Close    1649
# dtype: int64
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df["Close"] = sp500_df["Close"].str.replace("$", "")
sp500_df["Close"] = sp500_df["Close"].astype("float")
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_dailyreturns = sp500_df.pct_change()

# %%
# Drop nulls
sp500_dailyreturns = sp500_dailyreturns.dropna().copy()
sp500_dailyreturns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_dailyreturns = sp500_dailyreturns.rename(columns={"Close": "SnP500_DR"})
sp500_dailyreturns.head()
# Out:
#             SnP500_DR
# Date
# 2012-10-02   0.000872
# 2012-10-03   0.003624
# 2012-10-04   0.007174
# 2012-10-05  -0.000322
# 2012-10-08  -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
joined_df = pd.concat([whalereturns_df, algoreturns_df, sp500_dailyreturns], axis='columns', join='inner')
joined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SnP500_DR
# Date
# 2015-03-03 -0.000949  -0.004539
# 2015-03-04  0.002416  -0.004389
# 2015-03-05  0.004323   0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Analysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
joined_df.plot(figsize=(10,5))
whalereturns_df.plot(figsize=(10,5))
algoreturns_df.plot(figsize=(10,5))
sp500_dailyreturns.plot(figsize=(10,5))

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns_joined  = (1 +  joined_df).cumprod() - 1
print(cumulative_returns_joined.head())
# Plot cumulative returns
cumulative_returns_joined.plot(figsize=(10,5), title="Cumulative Returns of All Portfolios")
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000962           -0.001755
# 2015-03-05                   0.004981            0.002314
# 2015-03-06                  -0.002963           -0.001269
# 2015-03-09                  -0.002383            0.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.003028               -0.002383 -0.010514
# 2015-03-05                    -0.000681                0.004327 -0.011459
# 2015-03-06                    -0.009156               -0.008828 -0.016359
# 2015-03-09                    -0.003367               -0.010466 -0.021717
#
#               Algo 2  SnP500_DR
# Date
# 2015-03-03 -0.000949  -0.004539
# 2015-03-04  0.001464  -0.008907
# 2015-03-05  0.005794  -0.007722
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
whalereturns_df.plot.box()
algoreturns_df.plot.box()
sp500_dailyreturns.plot.box()

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
whalereturns_std = whalereturns_df.std()
algoreturns_std = algoreturns_df.std()

print(whalereturns_std.head())
algoreturns_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_dailyreturns_std = sp500_dailyreturns.std()
print(sp500_dailyreturns_std.head())
# Determine which portfolios are riskier than the S&P 500
joined_std = joined_df.std()
joined_std = joined_std.sort_values(ascending=False)
joined_std.head(10)
# Out:
# SnP500_DR    0.008111
# dtype: float64
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# SnP500_DR                      0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %% [markdown]
# ### RISKY PORTFOLIOS
# Based on the analysis abovethe Berkshire Hathaway and Tiger GLobal Mgmt protfolios are riskier than S&P 500
#
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = joined_std * np.sqrt(252)
annualized_std.head(10)
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# SnP500_DR                      0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
joined_df.rolling(window=21).std().plot()

# Plot the rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

correlation = joined_df.corr()

# Display de correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# SnP500_DR                                     0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a Algo 2 portfolio
joined_df.head()
covariance = joined_df['Algo 2'].cov(joined_df['SnP500_DR'])
covariance

# Calculate variance of S&P 500
variance = joined_df['SnP500_DR'].var()
variance
# Computing beta

algo1_beta = covariance/variance
algo1_beta

# Plot beta trend
rolling_covariance = joined_df['Algo 2'].rolling(window=30).cov(joined_df['SnP500_DR'])

rolling_variance = joined_df['SnP500_DR'].rolling(window=30).var()

rolling_beta = rolling_covariance / rolling_variance

rolling_beta.plot(figsize=(20, 10), title='Rolling 30-Day Beta of Algo 2 portfolio')

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (joined_df.mean() * 252) / (joined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SnP500_DR                      0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# The Algo 1 porfolio has a higher sharpe ratio and hence a more attractive risk-adjusted return. It outperfoms both the S&P500 and the whale portfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `CCL` - Carnival Cruise LLC- Leader in cruise sector
#
# * `RIG` - Transocean. Leading offshore drilling service provider
#
# * `JWN` - Nordstrom. Leading retailer and known for excellent customer service.

# %% [markdown]
# # Reading data from 1st stock
# # Reading algorithmic returns

# %%
ccl_path = Path("Resources/ccl_historical.csv")

ccl_df = pd.read_csv(ccl_path)
ccl_df.head().count()
ccl_df.dtypes
ccl_df.set_index(pd.to_datetime(ccl_df['Date'], infer_datetime_format=True), inplace=True)

ccl_df.drop(columns=['Date'], inplace=True)
ccl_df = ccl_df.rename(columns={
    "Close": "Carnival"
})
ccl_df.sort_index(inplace=True)
ccl_df.head()
#algoreturns_df.sort_index(inplace=True)
#algoreturns_df.head(
# Out:
#             Carnival
# Date
# 2012-10-01     36.02
# 2012-10-02     36.15
# 2012-10-03     36.57
# 2012-10-04     36.87
# 2012-10-05     37.13

# %%
# Reading data from 2nd stock
rig_path = Path("Resources/rig_historical.csv")

rig_df = pd.read_csv(rig_path)
rig_df.head().count()
rig_df.dtypes
rig_df.set_index(pd.to_datetime(rig_df['Date'], infer_datetime_format=True), inplace=True)

rig_df.drop(columns=['Date'], inplace=True)
rig_df = rig_df.rename(columns={
    "Close": "Transocean",
})

rig_df.sort_index(inplace=True)
rig_df.head()
# Out:
#             Transocean
# Date
# 2012-10-01       46.22
# 2012-10-02       46.02
# 2012-10-03       45.12
# 2012-10-04       46.05
# 2012-10-05       45.16

# %%
# Reading data from 3rd stock
jwn_path = Path("Resources/jwn_historical.csv")

jwn_df = pd.read_csv(jwn_path)
jwn_df.head().count()
jwn_df.dtypes
jwn_df.set_index(pd.to_datetime(jwn_df['Date'], infer_datetime_format=True), inplace=True)

jwn_df.drop(columns=['Date'], inplace=True)
jwn_df = jwn_df.rename(columns={
    "Close": "Nordstrom"
})
jwn_df.sort_index(inplace=True)
jwn_df.head()
# Out:
#             Nordstrom
# Date
# 2012-10-01      55.74
# 2012-10-02      55.63
# 2012-10-03      55.88
# 2012-10-04      56.05
# 2012-10-05      56.18

# %%
# Combine all stocks in a single DataFrame
joined_data = pd.concat([ccl_df, rig_df, jwn_df], axis="columns", join="inner")
joined_data.head()
# Out:
#             Carnival  Transocean  Nordstrom
# Date
# 2012-10-01     36.02       46.22      55.74
# 2012-10-02     36.15       46.02      55.63
# 2012-10-03     36.57       45.12      55.88
# 2012-10-04     36.87       46.05      56.05
# 2012-10-05     37.13       45.16      56.18

# %%
# Reset Date index
#joined_data = joined_data.reset_index()

# %%
# Reorganize portfolio data by having a column per symbol
joined_data.head()
# Out:
#             Carnival  Transocean  Nordstrom
# Date
# 2012-10-01     36.02       46.22      55.74
# 2012-10-02     36.15       46.02      55.63
# 2012-10-03     36.57       45.12      55.88
# 2012-10-04     36.87       46.05      56.05
# 2012-10-05     37.13       45.16      56.18

# %%
# Calculate daily returns

daily_returns = joined_data.pct_change()

# Drop NAs
daily_returns = daily_returns.dropna().copy()
# Display sample data
print(daily_returns.count())
daily_returns.head()
# Out:
# Carnival      1643
# Transocean    1643
# Nordstrom     1643
# dtype: int64
#             Carnival  Transocean  Nordstrom
# Date
# 2012-10-02  0.003609   -0.004327  -0.001973
# 2012-10-03  0.011618   -0.019557   0.004494
# 2012-10-04  0.008203    0.020612   0.003042
# 2012-10-05  0.007052   -0.019327   0.002319
# 2012-10-08  0.000539   -0.002436   0.004984

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = daily_returns.dot(weights)

# Display sample data
print(portfolio_returns.count())
portfolio_returns.head()
# Out:
# 1643
# Date
# 2012-10-02   -0.000897
# 2012-10-03   -0.001148
# 2012-10-04    0.010619
# 2012-10-05   -0.003319
# 2012-10-08    0.001029
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
joined_returns_df = pd.concat([joined_df, portfolio_returns], axis="columns", join="inner" )
print(joined_returns_df.head())
joined_returns_df = joined_returns_df.rename(columns={
    0: "PortfolioR"
})

joined_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SnP500_DR         0
# Date
# 2015-03-03 -0.000949  -0.004539 -0.006015
# 2015-03-04  0.002416  -0.004389  0.000988
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
joined_returns_df = joined_returns_df.dropna().copy()
joined_returns_df.count()
# Out:
# Carnival      1643
# Transocean    1643
# Nordstrom     1643
# PortfolioR    1643
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
joined_returns_std = joined_returns_df.std()
annualized_std = joined_returns_std * np.sqrt(252)
annualized_std.head()
# Out:
# Carnival      0.235681
# Transocean    0.472741
# Nordstrom     0.307254
# PortfolioR    0.229753
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_joined_std = joined_returns_df.rolling(window=21).std()
# Plot rolling standard deviation
rolling_joined_std.plot()

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_pf = joined_returns_df.corr()
correlation_pf.plot()

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
joined_returns_df.head()
# Covariance of  porfolios 
rolling_covariance = joined_returns_df['PortfolioR'].rolling(window=30).cov(joined_df['SnP500_DR'])
print(rolling_covariance.head())

# Variance of S&P 500
rolling_variance = joined_df['SnP500_DR'].rolling(window=30).var()
print(rolling_variance.head())

rolling_beta = rolling_covariance/rolling_variance
rolling_beta.plot(figsize=(20,10), title="Rolling 60-day Beta of Portfolio")
# Out:
# Date
# 2012-10-02   NaN
# 2012-10-03   NaN
# 2012-10-04   NaN
# 2012-10-05   NaN
# 2012-10-08   NaN
# dtype: float64
# Date
# 2015-03-03   NaN
# 2015-03-04   NaN
# 2015-03-05   NaN
# 2015-03-06   NaN
# 2015-03-09   NaN
# Name: SnP500_DR, dtype: float64

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
portfolio_sharpe_ratios = (joined_returns_df.mean() * 252) / (joined_returns_df.std() * np.sqrt(252))
portfolio_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.377606
# PAULSON & CO.INC.             -0.461739
# TIGER GLOBAL MANAGEMENT LLC   -0.094377
# BERKSHIRE HATHAWAY INC         0.651962
# Algo 1                         1.391743
# Algo 2                         0.495195
# SnP500_DR                      0.703453
# PortfolioR                    -0.013288
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
portfolio_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %% [markdown]
# ### How does your portfolio do?
#
# THe sharpe ratio of my portfolio is slightly negative which implies that the return on investment is slightly smaller than the risk-free rate
